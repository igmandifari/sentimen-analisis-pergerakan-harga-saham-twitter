# %% [markdown]
# ## Tweetvac

# %%
# !pip install twython
# !pip install tweetvac

# %%
import json

# %%
import tweetvac
#https://github.com/cash/tweetvac

# %%
vac = tweetvac.TweetVac(("2jFSYuo6jPAWyvRFtj6E0m7ZK", "ElLolsu8qve5LopnydAeEE2FMyOlfxXXcA2gJWAQxdBK5H1eLG", "252435619-KmFVGNocYXoc28BlIAh8QGxpeOOpsBVZTU0Oq15l", "Fc5MRRjPIVkxmCXY4IXGxM4RZ0zZnCEbjhkl4dELUVDeU"))

# %%
params = {'q': 'BBRI-filter:retweets', 'count': 2000, 'lang':'id', 'tweet_mode':'extended'}
data = vac.suck('search/tweets', params)

# %%
print(data)
# Out:
# [{'created_at': 'Tue Jul 20 01:39:27 +0000 2021', 'id': 1417298071831023646, 'id_str': '1417298071831023646', 'full_text': '@ceobluefess Kalo gadunnya mimin punya temen yg kaya gadunnya mimin kenalin ke gw dong min😭 mau nyari tapi susah\U0001f972 minimal uang bulanan, saham bbri &amp; bbca, sama kost an buat invest, udh itu cukup kok🌚', 'truncated': False, 'display_text_range': [13, 203], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ceobluefess', 'name': 'Mimin Base', 'id': 1322964363473428481, 'id_str': '1322964363473428481', 'indices': [0, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'in', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1417285520820903939, 'in_reply_to_status_id_str': '1417285520820903939', 'in_reply_to_user_id': 1322964363473428481, 'in_reply_to_user_id_str': '1322964363473428481', 'in_reply_to_screen_name': 'ceobluefess'
# ...

# %%
type(data)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#                          created_at  ...  quoted_status
# 0    Tue Jul 20 01:39:27 +0000 2021  ...            NaN
# 1    Mon Jul 19 16:16:26 +0000 2021  ...            NaN
# 2    Mon Jul 19 15:57:30 +0000 2021  ...            NaN
# 3    Mon Jul 19 12:18:18 +0000 2021  ...            NaN
# 4    Mon Jul 19 11:25:05 +0000 2021  ...            NaN
# ..                              ...  ...            ...
# 257  Mon Jul 12 00:36:16 +0000 2021  ...            NaN
# 258  Mon Jul 12 00:35:08 +0000 2021  ...            NaN
# 259  Mon Jul 12 00:22:22 +0000 2021  ...            NaN
# 260  Sun Jul 11 20:14:09 +0000 2021  ...            NaN
# 261  Sun Jul 11 18:07:19 +0000 2021  ...            NaN
#
# [262 rows x 30 columns]

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
import requests
import os
import json
with open('/content/gdrive/MyDrive/twitter-data1.json', 'w') as f:
    json.dump(data, f)
    f.write('\n')
